# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
from pathlib import Path
import pandas as pd
import scipy.stats as stats
import os

# %%
df = Path('../Data/airlines_2005_iad_origin.csv')

df = pd.read_csv(df)

df.head()
# Out:
#    ActualElapsedTime  AirTime  ArrDelay  ArrTime  CRSArrTime  CRSDepTime  \
# 0               86.0     70.0     -23.0   1346.0        1409        1230
# 1              130.0     69.0      41.0   2033.0        1952        1805
# 2              324.0    299.0     -24.0   1957.0        2021        1736
# 3               72.0     50.0     -11.0   1353.0        1404        1245
# 4               53.0     39.0     -11.0    806.0         817         715
#
#    CRSElapsedTime CancellationCode  Cancelled  CarrierDelay  ...  Month  \
# 0            99.0              NaN          0           0.0  ...      3
# 1           107.0              NaN          0           0.0  ...      9
# 2           345.0              NaN          0           NaN  ...     10
# 3            79.0              NaN          0           0.0  ...      6
# 4            62.0              NaN          0           0.0  ...     10
#
#    NASDelay  Origin  SecurityDelay TailNum  TaxiIn  TaxiOut  UniqueCarrier  \
# 0       0.0     IAD            0.0  N680BR     4.0     11.0             DH
# 1      23.0     IAD            0.0  N814CA     2.0     59.0             OH
# 2       NaN     IAD            NaN  N583UA     6.0     19.0             UA
# 3       0.0     IAD            0.0  N691BR     3.0     19.0             DH
# 4       0.0     IAD            0.0  N319UE     5.0      8.0             DH
#
#    WeatherDelay  Year
# 0           0.0  2004
# 1          18.0  2004
# 2           NaN  2008
# 3           0.0  2004
# 4           0.0  2003
#
# [5 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 786380 entries, 0 to 786379
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ActualElapsedTime  762634 non-null  float64
#  1   AirTime            762634 non-null  float64
#  2   ArrDelay           762634 non-null  float64
#  3   ArrTime            762677 non-null  float64
#  4   CRSArrTime         786380 non-null  int64
#  5   CRSDepTime         786380 non-null  int64
#  6   CRSElapsedTime     786363 non-null  float64
#  7   CancellationCode   13702 non-null   object
#  8   Cancelled          786380 non-null  int64
#  9   CarrierDelay       522404 non-null  float64
#  10  DayOfWeek          786380 non-null  int64
#  11  DayofMonth         786380 non-null  int64
#  12  DepDelay           764192 non-null  float64
#  13  DepTime            764192 non-null  float64
#  14  Dest               786380 non-null  object
#  15  Distance           786380 non-null  float64
#  16  Diverted           786380 non-null  int64
#  17  FlightNum          786380 non-null  int64
#  18  LateAircraftDelay  522404 non-null  float64
#  19  Month              786380 non-null  int64
#  20  NASDelay           522404 non-null  float64
#  21  Origin             786380 non-null  object
#  22  SecurityDelay      522404 non-null  float64
#  23  TailNum            785158 non-null  object
#  24  TaxiIn             784157 non-null  float64
#  25  TaxiOut            784309 non-null  float64
#  26  UniqueCarrier      786380 non-null  object
#  27  WeatherDelay       522404 non-null  float64
#  28  Year               786380 non-null  int64
# dtypes: float64(15), int64(9), object(5)
# memory usage: 174.0+ MB
