# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
from pathlib import Path
import pandas as pd
import scipy.stats as stats
import os

# %%
df = Path('../Data/airlines_2005_1.csv')

df = pd.read_csv(df)

df.head()
# Out:
#    ActualElapsedTime  AirTime  ArrDelay  ArrTime  CRSArrTime  CRSDepTime  \
# 0               49.0     37.0     -19.0   1054.0        1113        1008
# 1               43.0     19.0      12.0    850.0         838         745
# 2               65.0     31.0      26.0   1000.0         934         832
# 3               40.0     17.0      84.0   1047.0         923         840
# 4                NaN      NaN       NaN      NaN        1110         645
#
#    CRSElapsedTime CancellationCode  Cancelled  CarrierDelay  ...  Month  \
# 0            65.0              NaN          0           0.0  ...      1
# 1            53.0              NaN          0           0.0  ...      1
# 2            62.0              NaN          0          23.0  ...      1
# 3            43.0              NaN          0           0.0  ...      1
# 4           205.0                B          1           0.0  ...      1
#
#    NASDelay  Origin  SecurityDelay TailNum  TaxiIn  TaxiOut  UniqueCarrier  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 594924 entries, 0 to 594923
# Data columns (total 29 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ActualElapsedTime  568031 non-null  float64
#  1   AirTime            568031 non-null  float64
#  2   ArrDelay           568031 non-null  float64
#  3   ArrTime            568031 non-null  float64
#  4   CRSArrTime         594924 non-null  int64
#  5   CRSDepTime         594924 non-null  int64
#  6   CRSElapsedTime     594924 non-null  float64
#  7   CancellationCode   25085 non-null   object
#  8   Cancelled          594924 non-null  int64
#  9   CarrierDelay       594924 non-null  float64
#  10  DayOfWeek          594924 non-null  int64
#  11  DayofMonth         594924 non-null  int64
#  12  DepDelay           569840 non-null  float64
#  13  DepTime            569840 non-null  float64
#  14  Dest               594924 non-null  object
# ...

# %%
df[(df.Origin == 'IAD') | (df.Dest == 'IAD')]
# Out:
#         ActualElapsedTime  AirTime  ArrDelay  ArrTime  CRSArrTime  CRSDepTime  \
# 7                   120.0     81.0      13.0   1117.0        1104         923
# 15                  151.0    130.0     -14.0   2016.0        2030        1735
# 20                  110.0     74.0      -4.0   1906.0        1910        1725
# 29                   67.0     54.0     -23.0   1952.0        2015        1845
# 46                   67.0     39.0       0.0    959.0         959         855
# ...                   ...      ...       ...      ...         ...         ...
# 594683               67.0     36.0      28.0   1027.0         959         855
# 594785              207.0    171.0       5.0   1037.0        1032         811
# 594812              108.0     74.0      10.0   1622.0        1612        1432
# 594847              290.0    262.0       4.0   1749.0        1745        1500
# 594906               90.0     74.0     -21.0   2239.0        2300        2115
#
# ...
