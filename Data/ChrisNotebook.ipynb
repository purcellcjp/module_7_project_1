# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline
from pathlib import Path
import pandas as pd
import scipy.stats as stats
import os

# %%
df = Path('../Data/airlines_2005_iad_origin.csv')

df = pd.read_csv(df)

df.head()
# Out:
#    ActualElapsedTime  AirTime  ArrDelay  ArrTime  CRSArrTime  CRSDepTime  \
# 0               86.0     70.0     -23.0   1346.0        1409        1230
# 1              130.0     69.0      41.0   2033.0        1952        1805
# 2              324.0    299.0     -24.0   1957.0        2021        1736
# 3               72.0     50.0     -11.0   1353.0        1404        1245
# 4               53.0     39.0     -11.0    806.0         817         715
#
#    CRSElapsedTime CancellationCode  Cancelled  CarrierDelay  ...  Month  \
# 0            99.0              NaN          0           0.0  ...      3
# 1           107.0              NaN          0           0.0  ...      9
# 2           345.0              NaN          0           NaN  ...     10
# 3            79.0              NaN          0           0.0  ...      6
# 4            62.0              NaN          0           0.0  ...     10
#
#    NASDelay  Origin  SecurityDelay TailNum  TaxiIn  TaxiOut  UniqueCarrier  \
# ...

# %%
df[df.WeatherDelay > 0]
# Out:
#         ActualElapsedTime  AirTime  ArrDelay  ArrTime  CRSArrTime  CRSDepTime  \
# 1                   130.0     69.0      41.0   2033.0        1952        1805
# 44                  232.0    194.0      84.0   1648.0        1524        1250
# 101                 167.0     99.0     162.0   1230.0         948         850
# 234                 357.0    310.0      34.0   2136.0        2102        1810
# 422                  81.0     57.0     237.0   2233.0        1836        1708
# ...                   ...      ...       ...      ...         ...         ...
# 786103              154.0    139.0      38.0   1649.0        1611        1435
# 786171              126.0    109.0     176.0   2326.0        2030        1810
# 786207              146.0    129.0      34.0   1044.0        1010         745
# 786350              303.0    266.0      76.0   1809.0        1653        1440
# 786368              117.0     44.0      30.0   1837.0        1807        1638
#
# ...

# %%
df[df.CRSDepTime]
# Out:
# Year
# 2004    132797
# 2005    122342
# 2003    103386
# 2006     96010
# 2007     91048
# 2008     76031
# 2000     65462
# 2001     54869
# 2002     44435
# Name: count, dtype: int64
